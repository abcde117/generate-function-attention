# %%
from ori_model import *
from models import *

from ult import *

# %%
from torchvision import datasets, transforms

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# # mnist

# %%
transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor()
])


mnist_dataset = datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=transform
)

# %%
models={
    "vit_po":MiniVT_PO(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pf":MiniVT_PF(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pok":MiniVT_POK(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pfk":MiniVT_PFK(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_base":MiniVT_ORI(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2)}

# %%
models={
    "vit_po":MiniVT_PO(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pf":MiniVT_PF(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pok":MiniVT_POK(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pfk":MiniVT_PFK(d_in=1,d_out=8, d_model=16,patch_size=4,img_size=32,depth=2)}

# %%
for name,model in models.items():
    print_model_mib(model,name)
# Out:
# === vit_po ===
# Parameters : 7,936
# Param size : 0.030 MiB
# Buffer size: 0.000 MiB
# Total size : 0.030 MiB
# === vit_pf ===
# Parameters : 7,936
# Param size : 0.030 MiB
# Buffer size: 0.000 MiB
# Total size : 0.030 MiB
# === vit_pok ===
# Parameters : 7,936
# Param size : 0.030 MiB
# Buffer size: 0.000 MiB
# Total size : 0.030 MiB
# === vit_pfk ===
# Parameters : 7,936
# Param size : 0.030 MiB
# Buffer size: 0.000 MiB
# Total size : 0.030 MiB
# === vit_base ===
# Parameters : 7,936
# Param size : 0.030 MiB
# Buffer size: 0.000 MiB
# Total size : 0.030 MiB

# %%
runner = ExperimentRunner(
    models=models,
    dataset=mnist_dataset,
    num_folds=2,
    num_epochs=20,
    batch_size=128,
    lr=1e-3,
    task_type="classification",
    classifier_in=8,

)

logs=runner.run()
# Out:
# >>> Model: vit_po
#
# --- Fold 0 ---
# vit_po | Fold 0 | Epoch 1 | TrainAcc=0.2781 | ValAcc=0.4150
# vit_po | Fold 0 | Epoch 2 | TrainAcc=0.5017 | ValAcc=0.5765
# vit_po | Fold 0 | Epoch 3 | TrainAcc=0.6233 | ValAcc=0.6588
# vit_po | Fold 0 | Epoch 4 | TrainAcc=0.7015 | ValAcc=0.6994
# vit_po | Fold 0 | Epoch 5 | TrainAcc=0.7400 | ValAcc=0.7613
# vit_po | Fold 0 | Epoch 6 | TrainAcc=0.7677 | ValAcc=0.7872
# vit_po | Fold 0 | Epoch 7 | TrainAcc=0.7802 | ValAcc=0.7765
# vit_po | Fold 0 | Epoch 8 | TrainAcc=0.7977 | ValAcc=0.8106
# vit_po | Fold 0 | Epoch 9 | TrainAcc=0.8130 | ValAcc=0.7993
# vit_po | Fold 0 | Epoch 10 | TrainAcc=0.8216 | ValAcc=0.8029
# vit_po | Fold 0 | Epoch 11 | TrainAcc=0.8253 | ValAcc=0.8358
# vit_po | Fold 0 | Epoch 12 | TrainAcc=0.8330 | ValAcc=0.8353
# vit_po | Fold 0 | Epoch 13 | TrainAcc=0.8432 | ValAcc=0.8415
# vit_po | Fold 0 | Epoch 14 | TrainAcc=0.8444 | ValAcc=0.8520
# vit_po | Fold 0 | Epoch 15 | TrainAcc=0.8504 | ValAcc=0.8405
# ...

# %%
save_experiment_csv(logs, "experiment_logs_so_ko.csv")

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_gelu.csv")

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_nosqrt.csv")
# Out:
# 📁 Saved experiment results to: experiment_logs_so_ko_nosqrt.csv

# %% [markdown]
# # cifr

# %%
transform = transforms.Compose([
   transforms.Resize((32, 32)),


   transforms.ToTensor()
])


cifar_dataset = datasets.CIFAR10(
   root="./data",
   train=True,
   download=True,
   transform=transform
)

# %%
models={
    "vit_po":MiniVT_PO(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pf":MiniVT_PF(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pok":MiniVT_POK(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pfk":MiniVT_PFK(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_base":MiniVT_ORI(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2)}

# %%
models2={
    "vit_po":MiniVT_PO(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pf":MiniVT_PF(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pok":MiniVT_POK(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2),
    "vit_pfk":MiniVT_PFK(d_in=3,d_out=10, d_model=16,patch_size=4,img_size=32,depth=2)}

# %%
for name,model in models.items():
    print_model_mib(model,name)
# Out:
# === vit_po ===
# Parameters : 8,482
# Param size : 0.032 MiB
# Buffer size: 0.000 MiB
# Total size : 0.032 MiB
# === vit_pf ===
# Parameters : 8,482
# Param size : 0.032 MiB
# Buffer size: 0.000 MiB
# Total size : 0.032 MiB
# === vit_pok ===
# Parameters : 8,482
# Param size : 0.032 MiB
# Buffer size: 0.000 MiB
# Total size : 0.032 MiB
# === vit_pfk ===
# Parameters : 8,482
# Param size : 0.032 MiB
# Buffer size: 0.000 MiB
# Total size : 0.032 MiB
# === vit_base ===
# Parameters : 8,482
# Param size : 0.032 MiB
# Buffer size: 0.000 MiB
# Total size : 0.032 MiB

# %%
runner = ExperimentRunner(
    models=models2,
    dataset=cifar_dataset, 
    num_folds=2,
    num_epochs=20,
    batch_size=128,
    lr=1e-3,
    task_type="classification",
    classifier_in=10,

)

logs=runner.run()
# Out:
# >>> Model: vit_po
#
# --- Fold 0 ---
# vit_po | Fold 0 | Epoch 1 | TrainAcc=0.1725 | ValAcc=0.1975
# vit_po | Fold 0 | Epoch 2 | TrainAcc=0.2173 | ValAcc=0.2218
# vit_po | Fold 0 | Epoch 3 | TrainAcc=0.2398 | ValAcc=0.2405
# vit_po | Fold 0 | Epoch 4 | TrainAcc=0.2501 | ValAcc=0.2632
# vit_po | Fold 0 | Epoch 5 | TrainAcc=0.2642 | ValAcc=0.2644
# vit_po | Fold 0 | Epoch 6 | TrainAcc=0.2837 | ValAcc=0.2885
# vit_po | Fold 0 | Epoch 7 | TrainAcc=0.2972 | ValAcc=0.2879
# vit_po | Fold 0 | Epoch 8 | TrainAcc=0.2987 | ValAcc=0.2972
# vit_po | Fold 0 | Epoch 9 | TrainAcc=0.3103 | ValAcc=0.3090
# vit_po | Fold 0 | Epoch 10 | TrainAcc=0.3144 | ValAcc=0.2968
# vit_po | Fold 0 | Epoch 11 | TrainAcc=0.3204 | ValAcc=0.3253
# vit_po | Fold 0 | Epoch 12 | TrainAcc=0.3214 | ValAcc=0.3249
# vit_po | Fold 0 | Epoch 13 | TrainAcc=0.3239 | ValAcc=0.3199
# vit_po | Fold 0 | Epoch 14 | TrainAcc=0.3293 | ValAcc=0.3269
# vit_po | Fold 0 | Epoch 15 | TrainAcc=0.3315 | ValAcc=0.3198
# ...

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_cifr10.csv")

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_cifr10_epo30.csv")
# Out:
# 📁 Saved experiment results to: experiment_logs_so_ko_cifr10_epo30.csv

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_cifr10_gelu.csv")

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_cifr10_gelu_epo30.csv")
# Out:
# 📁 Saved experiment results to: experiment_logs_so_ko_cifr10_gelu_epo30.csv

# %%
save_experiment_csv(logs, "experiment_logs_so_ko_cifr10_nosqrt.csv")
# Out:
# 📁 Saved experiment results to: experiment_logs_so_ko_cifr10_nosqrt.csv
